# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaSamusenkova/DataAnalisysInnopolis/blob/main/%D0%A1%D0%B0%D0%BC%D1%83%D1%81%D0%B5%D0%BD%D0%BA%D0%BE%D0%B2%D0%B0_%D0%9C_%D0%A1__%D0%94%D0%97%E2%84%962_%D0%B1%D0%BB%D0%BE%D0%BA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('coffee.csv')
data
# Out:
#     Location.Country                Location.Region  Location.Altitude.Min  \
# 0      United States                           kona                      0
# 1             Brazil  sul de minas - carmo de minas                     12
# 2             Brazil  sul de minas - carmo de minas                     12
# 3           Ethiopia                         sidamo                      0
# 4           Ethiopia                         sidamo                      0
# ..               ...                            ...                    ...
# 984        Guatemala                     san marcos                   1700
# 985         Honduras                      comayagua                   1400
# 986            India    chikmagalur karnataka indua                   3170
# 987            India    chikmagalur karnataka india                   3140
# 988         Honduras                 western region                   1200
#
#      Location.Altitude.Max  Location.Altitude.Average  Year  \
# ...

# %% [markdown]
# Датасет содержит 989 строк и 23 столбца. Он описывает всевозможные показатели, характеристики, такие как кислотность, плотность, аромат и др. сортов кофе арабики и робусты из разных стран, также учитывается высота над уровнем моря места произрастания, сорт, год урожая, общий объем урожая по количеству мешков и весу мешка, способ обработки зерна.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Location.Country                989 non-null    object
#  1   Location.Region                 953 non-null    object
#  2   Location.Altitude.Min           989 non-null    int64
#  3   Location.Altitude.Max           989 non-null    int64
#  4   Location.Altitude.Average       989 non-null    int64
#  5   Year                            989 non-null    int64
#  6   Data.Owner                      984 non-null    object
#  7   Data.Type.Species               989 non-null    object
#  8   Data.Type.Variety               864 non-null    object
#  9   Data.Type.Processing method     927 non-null    object
#  10  Data.Production.Number of bags  989 non-null    int64
#  11  Data.Production.Bag weight      989 non-null    float64
# ...

# %% [markdown]
# Численные значения, как целые, так и с дробной частью содержатся в большинстве столбцов, поскольку оценка по характеристикам кофе дана в основном в числовом виде, возможно балльном, кроме характеристики "Цвет/Color". В строчном /object/ типе представлены данные по 7 столбцам: Страна, Регион, Владелец, Сорт, Подвид, Способ обработки, Цвет. Нулевые значения есть в столбцах Регион /36/, Владелец /5/, Подвид /125/, Способ обработки /62/.

# %%
data.describe()
# Out:
#        Location.Altitude.Min  Location.Altitude.Max  \
# count             989.000000             989.000000
# mean             1640.076845            1675.929221
# std              9192.519762            9191.957731
# min                 0.000000               0.000000
# 25%               905.000000             950.000000
# 50%              1300.000000            1310.000000
# 75%              1550.000000            1600.000000
# max            190164.000000          190164.000000
#
#        Location.Altitude.Average         Year  Data.Production.Number of bags  \
# count                 989.000000   989.000000                      989.000000
# mean                 1657.998989  2013.549039                      151.761375
# std                  9192.058989     1.658883                      125.665490
# min                     0.000000  2010.000000                        1.000000
# 25%                   950.000000  2012.000000                       15.000000
# ...

# %% [markdown]
# Сомнение вызывает максимальное значение высоты над уровнем моря Altitude /190164/, поскольку не понятно, в каких величинах приведены значения, самая высоткая точка в мире составляет 8849 м над уровнем моря, похоже на выброс. Также странно, что все три колонки высоты Altitude, минимальная-максимальная-средняя, содержат это максимальное значение, и в целом по статистическим данным практически повторяют друг друга.
# Также странное значение имеет максимальное значение веса мешка /19200/, также не понятно, в каких величинах даны значения, если в кг, то такое значение похоже на выброс.
# При этом минимальное количество мешков - /1/, а минимальный вес мешка - /0/, что также наводит на мысли о некорректности данных, либо для таблицы установлено, что количество мешков не может быть нулевым.
# Все характеристики сортов содержат значения min /0/, что говорит о том, что некоторые сорта не были оценены, и чтобы не оставлять пустые значения, они были заполнены числом /0/.
